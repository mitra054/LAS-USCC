# %%
import numpy as np
from scipy import linalg
from pyscf import gto, scf, lib, mcscf
from mrh.my_pyscf.mcscf.lasscf_o0 import LASSCF
from mrh.exploratory.citools import fockspace
from mrh.exploratory.unitary_cc import lasuccsd as lasuccsd
from mrh.exploratory.unitary_cc.uccsd_sym0 import get_uccs_op
from mrh.exploratory.unitary_cc.uccsd_sym0 import get_uccsd_op
import itertools

# %%
xyz = '''H 0.0 0.0 0.0
         H 1.0 0.0 0.0
         H 0.2 3.9 0.1
         H 1.159166 4.1 -0.1'''
mol = gto.M (atom = xyz, basis = 'sto-3g', output='h4_sto3g.log.py',
    verbose=0)
mf = scf.RHF (mol).run ()
ref = mcscf.CASSCF (mf, 4, 4).run () # = FCI
las = LASSCF (mf, (2,2), (2,2), spin_sub=(1,1))
las.verbose=1
frag_atom_list = ((0,1),(2,3))
mo_loc = las.localize_init_guess (frag_atom_list, mf.mo_coeff)
las.kernel (mo_loc)
# Out:
# (-2.20228218386414,
#  [-1.629577159323385, -1.629416492754478],
#  [[array([[ 9.84512094e-01, -1.79507818e-20],
#           [-1.72516898e-20, -1.75316678e-01]])],
#   [array([[ 9.84512149e-01,  5.94566477e-21],
#           [ 4.35297947e-21, -1.75316366e-01]])]],
#  array([[ 5.78118277e-01, -9.96451500e-01, -6.38874766e-04,
#           1.26992535e-03],
#         [ 5.77939050e-01,  9.96555269e-01, -5.75922559e-04,
#           4.26768779e-04],
#         [-2.16738269e-04,  3.82011442e-04,  5.77970367e-01,
#          -9.96539554e-01],
#         [-1.01717579e-03, -4.63634417e-04,  5.78087462e-01,
#           9.96468530e-01]]),
#  array([0., 0., 0., 0.]),
#  array([[ 6.26403927e-01, -3.50661525e-05,  6.21707661e-01,
#          -2.42611614e-04,  1.84382255e-05,  1.30828665e-01,
#           5.67578593e-04, -1.13093454e-04, -4.42538537e-03,
#           1.29979632e-01, -3.50661525e-05,  1.96791055e-01,
#           3.24474550e-05,  4.72660450e-06, -1.65621937e-04,
#           6.82901546e-04, -5.66316023e-05,  2.64708703e-04,
#           2.44006603e-03,  4.65467085e-04, -2.42611614e-04,
#           4.72660450e-06, -2.50034294e-04,  1.35232840e-06,
#           4.99377035e-08, -2.59185696e-04, -5.51305271e-07,
#           4.67025342e-07, -1.12109084e-04, -2.63620322e-04,
#           5.67578593e-04, -5.66316023e-05,  5.69568092e-04,
#          -5.51305271e-07,  2.53905806e-07, -3.15488020e-04,
#           1.40321068e-06, -3.16828343e-07, -1.63722151e-04,
#          -3.29211123e-04],
#         [-3.50661525e-05,  1.96791055e-01,  3.24474550e-05,
#           4.72660450e-06, -1.65621937e-04,  6.82901546e-04,
#          -5.66316023e-05,  2.64708703e-04,  2.44006603e-03,
#           4.65467085e-04,  6.21707661e-01,  3.24474550e-05,
#           6.53071157e-01, -2.50034294e-04,  1.93114842e-05,
#           1.29798828e-01,  5.69568092e-04, -1.26753629e-04,
#          -4.28687761e-03,  1.29009522e-01,  1.84382255e-05,
#          -1.65621937e-04,  1.93114842e-05,  4.99377035e-08,
#           3.09565833e-07, -2.34061368e-05,  2.53905806e-07,
#          -2.69819206e-07, -5.59817680e-05, -2.79341976e-05,
#          -1.13093454e-04,  2.64708703e-04, -1.26753629e-04,
#           4.67025342e-07, -2.69819206e-07, -1.14618174e-04,
#          -3.16828343e-07,  5.82077046e-07, -2.77930006e-05,
#          -1.26863124e-04],
#         [-2.42611614e-04,  4.72660450e-06, -2.50034294e-04,
#           1.35232840e-06,  4.99377035e-08, -2.59185696e-04,
#          -5.51305271e-07,  4.67025342e-07, -1.12109084e-04,
#          -2.63620322e-04,  1.84382255e-05, -1.65621937e-04,
#           1.93114842e-05,  4.99377035e-08,  3.09565833e-07,
#          -2.34061368e-05,  2.53905806e-07, -2.69819206e-07,
#          -5.59817680e-05, -2.79341976e-05,  1.30828665e-01,
#           6.82901546e-04,  1.29798828e-01, -2.59185696e-04,
#          -2.34061368e-05,  6.26404736e-01, -3.15488020e-04,
#          -1.14618174e-04,  2.21126331e-05,  6.21708217e-01,
#          -4.42538537e-03,  2.44006603e-03, -4.28687761e-03,
#          -1.12109084e-04, -5.59817680e-05,  2.21126331e-05,
#          -1.63722151e-04, -2.77930006e-05,  1.96791283e-01,
#          -2.29877499e-05],
#         [ 5.67578593e-04, -5.66316023e-05,  5.69568092e-04,
#          -5.51305271e-07,  2.53905806e-07, -3.15488020e-04,
#           1.40321068e-06, -3.16828343e-07, -1.63722151e-04,
#          -3.29211123e-04, -1.13093454e-04,  2.64708703e-04,
#          -1.26753629e-04,  4.67025342e-07, -2.69819206e-07,
#          -1.14618174e-04, -3.16828343e-07,  5.82077046e-07,
#          -2.77930006e-05, -1.26863124e-04, -4.42538537e-03,
#           2.44006603e-03, -4.28687761e-03, -1.12109084e-04,
#          -5.59817680e-05,  2.21126331e-05, -1.63722151e-04,
#          -2.77930006e-05,  1.96791283e-01, -2.29877499e-05,
#           1.29979632e-01,  4.65467085e-04,  1.29009522e-01,
#          -2.63620322e-04, -2.79341976e-05,  6.21708217e-01,
#          -3.29211123e-04, -1.26863124e-04, -2.29877499e-05,
#           6.53071520e-01]]),
#  NPArrayWithTag([[[[9.98726268e-01, 3.48315002e-01, 1.54698618e-03,
#                     5.18730820e-04],
#                    [3.48315002e-01, 1.00107822e+00, 1.19214218e-03,
#                     9.23154210e-04],
#                    [1.54698618e-03, 1.19214218e-03, 1.00765897e+00,
#                     3.48220259e-01],
#                    [5.18730820e-04, 9.23154210e-04, 3.48220259e-01,
#                     9.92306530e-01]],
#
#                   [[9.98726268e-01, 3.48315002e-01, 1.54698618e-03,
#                     5.18730820e-04],
#                    [3.48315002e-01, 1.00107822e+00, 1.19214218e-03,
#                     9.23154210e-04],
#                    [1.54698618e-03, 1.19214218e-03, 1.00765897e+00,
#                     3.48220259e-01],
#                    [5.18730820e-04, 9.23154210e-04, 3.48220259e-01,
#                     9.92306530e-01]]]]))

# %%
mc = mcscf.CASCI (mf, 4, 4)
mc.mo_coeff = las.mo_coeff
mc.fcisolver = lasuccsd.FCISolver (mol)
mc.fcisolver.norb_f = [2,2] # Number of orbitals per fragment
mc.verbose=5
mc.kernel()
print("34--------------------")

print ("FCI energy:      {:.9f}".format (ref.e_tot))
print ("LASSCF energy:   {:.9f}".format (las.e_tot))
print ("LASUCCSD energy: {:.9f}\n".format (mc.e_tot))

# mc.ci has to be a full CI vector ndarray. In order to access more
# information, a "LASUCCTrialState" object is cached on the fcisolver
psi = mc.fcisolver.psi

x = psi.x # Amplitude vector that solves the BFGS problem 
# The trailing elements of x are all zero because the fragment CI vectors
# are updated at the end of a calculation.
# print("Print x",x)
h1, h0 = mc.get_h1eff ()
h2 = mc.get_h2eff ()
h = [h0, h1, h2] # 2nd-quantized CAS Hamiltonian
energy, gradient = psi.e_de (x, h)
print ("Recomputing LASUCC total energy with cached objective function")
print ("LASUCCSD energy: {:.9f}".format (energy))
print ("|gradient| = {:.3e}".format (linalg.norm (gradient)))
print ("If that seems too high to you, consider: BFGS sucks.\n")


all_g, g, gen_indices, a_idxs_new, i_idxs_new, num_a_idxs, num_i_idxs = psi.get_grad_t1 (x, h, epsilon=2.0)

print ('Number of a_idxs in input',num_a_idxs)
print ('Number of i_idxs in input',num_i_idxs)
#exc_list = psi.get_excitation_list()
# Get the CI coefficients from psi
ci_f = psi.ci_f
norb_f = psi.norb_f
print("--------------------")

mol = gto.M (atom = xyz, basis = 'sto-3g', output='h4_sto3g2.log.py',
    verbose=lib.logger.DEBUG)
mf = scf.RHF (mol).run ()
ref = mcscf.CASSCF (mf, 4, 4).run () # = FCI
# Out:
# 34--------------------
# FCI energy:      -2.202289468
# LASSCF energy:   -2.202282184
# LASUCCSD energy: -2.202289457
#
# Recomputing LASUCC total energy with cached objective function
# LASUCCSD energy: -2.202289457
# |gradient| = 2.377e-04
# If that seems too high to you, consider: BFGS sucks.
#
# Number of a_idxs in input 0
# Number of i_idxs in input 0
# --------------------
# overwrite output file: h4_sto3g2.log.py

# %%
# ... [the rest of your imports]
import matplotlib.pyplot as plt

# ... [the rest of your setup code]

epsilons = np.logspace(-5.5, -4, num=20)  # Generating epsilon values on a logarithmic scale
energies = []
lengths = []  # Store lengths of a_idxs_new for each epsilon

for epsilon in epsilons:
    all_g, g, gen_indices, a_idxs_new, i_idxs_new, num_a_idxs, num_i_idxs = psi.get_grad_t1(x, h, epsilon=epsilon)
    lengths.append(len(a_idxs_new))
    
    # Rest of your code that computes the energy for this epsilon
    mol = gto.M(atom=xyz, basis='sto-3g', output='h4_sto3g2.log.py',
                verbose=lib.logger.DEBUG)
    mf = scf.RHF(mol).run()
    mc_uscc = mcscf.CASCI(mf, 4, 4)
    mc_uscc.mo_coeff = las.mo_coeff
    mc_uscc.fcisolver = lasuccsd.FCISolver2(mol, a_idxs_new, i_idxs_new)
    mc_uscc.fcisolver.norb_f = [2,2]
    mc_uscc.verbose = 5
    mc_uscc.kernel()
    energies.append(mc_uscc.e_tot)

reference_energy = energies[-1]  # Taking the last energy as reference
relative_energies = [(e - reference_energy) * 627.509 * 1000 for e in energies]  # Convert to kcal/mol and then multiply by 1000

# Your provided energy values
fci_energy = ref.e_tot
lasscf_energy = las.e_tot
lasuccsd_energy = mc.e_tot

relative_fci = (fci_energy - reference_energy) * 627.509 * 1000
relative_lasscf = (lasscf_energy - reference_energy) * 627.509 * 1000
relative_lasuccsd = (lasuccsd_energy - reference_energy) * 627.509 * 1000

# Plotting
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(epsilons, relative_energies, '-o', label="Relative Energy (kcal/mol * 1000)")
ax.axhline(relative_fci, color='red', linestyle='--', label="Relative FCI Energy")
ax.axhline(relative_lasscf, color='green', linestyle='--', label="Relative LASSCF Energy")
ax.axhline(relative_lasuccsd, color='blue', linestyle='--', label="Relative LASUCCSD Energy")

ax.set_xscale('log')
ax.set_xlabel('Epsilon')
ax.set_ylabel('Delta E')
ax.invert_xaxis()  # Flip the direction of the x-axis
ax.grid(True, which="both", ls="--", c='0.65')

# Add lengths as text annotations
for i, (epsilon, length) in enumerate(zip(epsilons, lengths)):
    ax.text(epsilon, relative_energies[i], f"{length}", ha='center', va='bottom')

# Adjust the legend position using (x,y) tuple
ax.legend(loc=(0.5, 0.7), fontsize=10)
ax.set_title('Delta E (E - E_ref) vs Epsilon')
plt.figtext(0.7, 0.8, "Total number of parameters = 142", fontsize=10, ha='center')

# Save the figure as PNG
plt.savefig("energy_vs_epsilon_0.1.png", dpi=300)

# Show the plot
plt.show()
# Out:
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 67
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 63
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 60
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 60
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 56
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 56
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 48
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 48
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 36
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 20
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 4
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 2
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 0

# %%
# ... [the rest of your imports]
import matplotlib.pyplot as plt

# ... [the rest of your setup code]

epsilons = np.logspace(-5.2, -4.4, num=30)  # Generating epsilon values on a logarithmic scale
energies = []
lengths = []  # Store lengths of a_idxs_new for each epsilon

for epsilon in epsilons:
    all_g, g, gen_indices, a_idxs_new, i_idxs_new, num_a_idxs, num_i_idxs = psi.get_grad_t1(x, h, epsilon=epsilon)
    lengths.append(len(a_idxs_new))
    
    # Rest of your code that computes the energy for this epsilon
    mol = gto.M(atom=xyz, basis='sto-3g', output='h4_sto3g2.log.py',
                verbose=lib.logger.DEBUG)
    mf = scf.RHF(mol).run()
    mc_uscc = mcscf.CASCI(mf, 4, 4)
    mc_uscc.mo_coeff = las.mo_coeff
    mc_uscc.fcisolver = lasuccsd.FCISolver2(mol, a_idxs_new, i_idxs_new)
    mc_uscc.fcisolver.norb_f = [2,2]
    mc_uscc.verbose = 5
    mc_uscc.kernel()
    energies.append(mc_uscc.e_tot)

# Use LAS-UCCSD as reference
lasuccsd_energy = mc.e_tot
reference_energy = lasuccsd_energy
relative_energies = [(e - reference_energy) * 627.509* 1000 for e in energies]

# Your provided energy values
fci_energy = ref.e_tot
lasscf_energy = las.e_tot

relative_fci = (fci_energy - reference_energy) * 627.509 * 1000
relative_lasscf = (lasscf_energy - reference_energy) * 627.509 * 1000

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(epsilons, relative_energies, '-o', color='gray', label="Delta E (kcal/mol)")
ax.axhline(relative_fci, color='red', linestyle='solid', label="E_FCI - E_ref")
ax.axhline(relative_lasscf, color='green', linestyle='--', label="E_LASSCF - E_ref")
ax.axhline(0, color='blue', linestyle='--', label="E_LASUCCSD (Reference)")

ax.set_xscale('log')
ax.set_xlabel('Epsilon', fontsize=14)
ax.set_ylabel('Delta E', fontsize=14)
ax.invert_xaxis()  # Flip the direction of the x-axis
ax.grid(True, which="both", ls="--", c='0.65')

# Add lengths as text annotations
for i, (epsilon, length) in enumerate(zip(epsilons, lengths)):
    ax.text(epsilon, relative_energies[i], f"{length}", ha='center', va='bottom')

# Adjust the legend position using (x,y) tuple
ax.legend(loc=(0.6, 0.7), fontsize=14)
ax.set_title('Delta E (E - E_ref) vs Epsilon')
plt.figtext(0.68, 0.81, "Total number of parameters = 142", fontsize=14, ha='center')

# Save the figure as PNG
plt.savefig("energy_vs_epsilon_0.1.png", dpi=300)

# Show the plot
plt.show()
# Out:
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 56
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 56
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 56
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 56
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 56
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 54
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 48
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 48
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 48
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 48
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 36
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 36
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 36
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 28
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 20
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 20
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 10
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
# overwrite output file: h4_sto3g2.log.py
# len(self.symtab_uscc) 8
